# %% [markdown]
# # Урок 1. Комфорт и конфликт в профессиональном и личном общении

# %% [markdown]
# ## Задание 1. Пройти тест по материалам лекции.
# ![Sem1Sert.jpg](Sem1Sert.jpg)

# %% [markdown]
# ## Задание 2. Пройти тест на определение уровня ЭИ.
# Оба или один на выбор:
# https://psytests.org/eq/hall-run.html - эмоц.интелл по Холлу
# https://testometrika.com/intellectual/test-golmana-on-emotional-intelligence/ - эмоц.интел. по Гоулману.

# %% [markdown]
# Результат уровня эмоционального интеллекта по Холлу:
# ![Sem1Test1.jpg](Sem1Test1.jpg)

# %% [markdown]
# Результат уровня эмоционального интеллекта по Гоуману:
# ![Sem1Test2.jpg](Sem1Test2.jpg)

# %% [markdown]
# ## Задание 3. Составить индивидуальный план развития эмоционального интеллекта, определить, какой из элементов эмоционального интеллекта наиболее/наименее развит.

# %% [markdown]
# ### <center>Индивидуальный план развития эмоционального интеллекта</center>

# %% [markdown]
# 1. Оценка текущего уровня эмоционального интеллекта:
#    - Определить свои сильные и слабые стороны в области эмоционального интеллекта.
#    - Анализировать свои эмоциональные реакции в различных ситуациях.
#    - Обратить внимание на свою способность понимать и управлять своими эмоциями, а также на свою эмпатию к другим людям.

# %% [markdown]
# 2. Установление целей:
#    - Определить основные цели, которые я хочу достичь в области эмоционального интеллекта.
#    - Учитывать свои слабые стороны и выберите цели, которые помогут развить их.
#    - Сформулировать цели SMART (Specific, Measurable, Achievable, Relevant, Time-bound) для более эффективного планирования.

# %% [markdown]
# 3. Разработка конкретных шагов и действий:
#    - Определить конкретные шаги и действия, которые необходимо предпринять для достижения каждой цели.
#    - Разбить каждую цель на подцели и создайте план действий для каждой из них.
#    - Учитывать, что развитие эмоционального интеллекта требует постоянной практики и самоанализа.

# %% [markdown]
# 4. Постановка сроков выполнения:
#    - Установить сроки выполнения каждого шага и цели в целом.
#    - Разделить план на краткосрочные, среднесрочные и долгосрочные цели.
#    - Поставить напоминания о сроках выполнения, чтобы поддерживать мотивацию и дисциплину.

# %% [markdown]
# 5. Определение показателей и способов измерения прогресса:
#    - Определить показатели, которые помогут оценить прогресс в развитии эмоционального интеллекта.
#    - Использовать способы измерения, такие как самооценка, обратная связь от окружающих, дневник эмоционального состояния и т.д.
#    - Периодически переоценивать свой прогресс и вносить корректировки в план, если необходимо.

# %% [markdown]
# ### <center>Определение наиболее/наименее развитого элемента эмоционального интеллекта</center>

# %% [markdown]
# <table border="1">
# <tr><td><center><p><b>Основные элементы эмоционального интеллекта</b></p></center>
# </td>
# <td><center><p><b>Результат теста <br> по Холлу</p></b></center>
# </td>
# </tr>
# <tr><td><p><b>Эмоциональная осведомленность</b> – <i>это осознание и понимание своих эмоций, постоянное пополнение собственного словаря эмоций. Люди с высокой эмоциональной осведомленностью в большей мере, чем у другие осведомлены о своем внутреннем состоянии</i></p>
# </td>
# <td><center><p>30</p></center>
# </td>
# </tr>
# <tr><td><p><b>Управление своими эмоциями</b> – <i>это эмоциональная отходчивость, эмоциональная гибкость, другими словами – произвольное управление своими эмоциями</i></p>
# </td>
# <td><center><p>27</p></center>
# </td>
# </tr>
# <tr><td><p><b>Самомотивация</b> – <i>управление своим поведением, за счет управления эмоциями умение находить причины для реализации своих целей</i></p>
# </td>
# <td><center><p>29</p></center>
# </td>
# </tr>
# <tr><td><p><b>Эмпатия</b> – <i>это понимание эмоций других людей, умение сопереживать текущему эмоциональному состоянию другого человека, а так же готовность оказать поддержку. Это умение понять состояние человека по мимике, жестам, оттенкам речи, позе</i></p>
# </td>
# <td><center><p>26</p></center>
# </td>
# </tr>
# <tr><td><p><b>Управление эмоциями других</b> – <i>умение воздействовать на эмоциональное состояние других людей, умение эффективно общаться и взаимодействовать с другими людьми</i></p>
# </td>
# <td><center><p>26</p></center>
# </td>
# </tr>
# </table>

# %% [markdown]
# <u>**Вывод.**</u>
#
# Согласно результатам тестов у меня средний уровень эмоционального интеллекта. А это значит, что мне стоит приложить незначительные усилия, чтобы этот уровень увеличить. Тогда я смогу лучше осознавать свои и чужие эмоции, управлять ими, чувствовать переживания других, увеличите самоконтроль и самомотивацию. При этом:
#
#
# * у меня наиболее развиты следующие элементы эмоционального интеллекта - _эмоциональная осведомленность_, _самомотивация_;
#
#
# * мне необходимо сконцентрировать усилия на развитии следующих элементов эмоционального интеллекта - _эмпатия_, _управление эмоциями других_.
